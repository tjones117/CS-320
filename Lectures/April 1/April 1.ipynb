# %%
import numpy as np

a = np.arange(10)
b = a[::-1]
b
# Out:
# array([9, 8, 7, 6, 5, 4, 3, 2, 1, 0])

# %%
import numpy as np
a = np.arange(10)
half = a[:5]
a = a.copy()
half[0] += 50
print(a[0])
# Out:
# 0

# %% [markdown]
# # Part 3

# %%
import matplotlib.pyplot as plt
import numpy as np
a = plt.imread("bug.jpg")
a = a[700:1600, 400:1600, :]
plt.imshow(a)

# %%
a = plt.imread("bug.jpg")
a = a[::50, ::50, :]
plt.imshow(a)

# %%
a = plt.imread("bug.jpg")
N=2
a = a.mean(axis=N)
print(a.shape)
a
plt.imshow(a, cmap="gray")
# Out:
# (1688, 2521)
